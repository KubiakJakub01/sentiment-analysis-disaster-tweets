# %% [markdown]
# # Inference notebook
#
# Purpose of this notebook is to present performance of the model on given data or sentences.
# You can use model fine-tuned using this repository or you can use pretrained model from HuggingFace.
# You can use data from the test set or you can provide your own sentences.

# %%
# import libraries
import sys
import os
import numpy as np
import pandas as pd
from pathlib import Path
pd.options.display.max_colwidth = 100 # to display full text in columns

# %%
# Add parent path to sys.path
cwd = Path(os.getcwd())
sys.path.append(str(cwd.parents[1]))

# %%
# Import modules
from src.model.nlp_models_selector import get_model_and_tokenizer
from src.utils.text_cleaning import text_cleaning
from src.utils.get_predictions import get_prdiction

# %% [markdown]
# ## Load model
#
# You can load model from local directory or from HuggingFace.

# %%
MODEL_PATH = "KubiakJakub01/finetuned-distilbert-base-uncased"
model, tokenizer = get_model_and_tokenizer(MODEL_PATH)
# Out:
# Some layers from the model checkpoint at KubiakJakub01/finetuned-distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['dropout_19']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at KubiakJakub01/finetuned-distilbert-base-uncased and are newly initialized: ['dropout_59']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Load data
#
# You can use sample.csv or you can provide your own data.

# %%
PATH_TO_DATA = "sample.csv"
df = pd.read_csv(PATH_TO_DATA)
df.head(10)
# Out:
#       id       keyword           location  \
# 0   2668         crush  San Diego, Texas.
# 1   7721     panicking                 UK
# 2   7547      outbreak                NaN
# 3  10687         wreck                NaN
# 4   4547     emergency                NaN
# 5  10805       wrecked  probably not home
# 6   2332      collapse           Fakefams
# 7   3694       destroy         SEA Server
# 8    394  annihilation       Chandler, AZ
# 9   5602         flood                NaN
#
#                                                                                                   text  \
# 0                                                 Love love love do you remember your first crush ? ??
# 1        @ushiocomics I may be panicking a little I wasn't as fast submitting the form as I usually am
# 2  Families to sue over Legionnaires: More than 40 families affected by the fatal outbreak of Legio...
# 3                                                                                         I am a wreck
# 4  #EMERGENCY in Odai Bucharest Romania 600 Dogs Dying!They are so Hungry that they EAT EACH OTHER!...
# 5                                                             coleslaw #wrecked http://t.co/sijNBmCZIJ
# 6                                               Correction: Tent Collapse Story http://t.co/S7VYGeNJuv
# 7                                                                            dazzle destroy the fun ??
# 8  U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild H...
# 9  survived the plague\nfloated the flood\njust peeked our heads above the mud\nno one's immune\nde...
#
#    target
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
# 5       0
# 6       1
# 7       0
# 8       1
# 9       0

# %%
# Clean text
df["text"] = df["text"].apply(text_cleaning)

# %%
# Get predictions
id_list = df["id"].tolist()
text_list = df["text"].tolist()
batch_size = 8
predictions = get_prdiction(model, tokenizer, id_list, text_list, batch_size)
# Out:
# Sample text: ['love love love remember first crush ', ' may panicking little fast submitting form usually', 'families sue legionnaires families affected fatal outbreak legionnaires disease edinburgh ', 'wreck', ' odai bucharest romania dogs dying they hungry eat other ']
# Predictions: 100%|██████████| 20/20 [00:00<00:00, 191958.99it/s]

# %% [markdown]
# ### Show predictions
#
# * id - id of the sentence
# * score - score of the sentence. It is a probability that sentence is belong to target class
# * target - target of the sentence where:
#         1 is tweet about disaster
#         0 is tweet not about disaster

# %%
# Show results
predicted_list = [x["target"] for x in predictions]
score_list = [x["score"] for x in predictions]
df["predictions"] = predicted_list
df["score"] = score_list
df.head(10)
# Out:
#       id       keyword           location  \
# 0   2668         crush  San Diego, Texas.
# 1   7721     panicking                 UK
# 2   7547      outbreak                NaN
# 3  10687         wreck                NaN
# 4   4547     emergency                NaN
# 5  10805       wrecked  probably not home
# 6   2332      collapse           Fakefams
# 7   3694       destroy         SEA Server
# 8    394  annihilation       Chandler, AZ
# 9   5602         flood                NaN
#
#                                                                                                   text  \
# 0                                                                 love love love remember first crush
# 1                                                    may panicking little fast submitting form usually
# 2           families sue legionnaires families affected fatal outbreak legionnaires disease edinburgh
# 3                                                                                                wreck
# 4                                             odai bucharest romania dogs dying they hungry eat other
# 5                                                                                            coleslaw
# 6                                                                      correction tent collapse story
# 7                                                                                  dazzle destroy fun
# 8        u s national park services tonto national forest stop annihilation salt river wild horse via
# 9  survived plague\nfloated flood\njust peeked heads mud\nno one immune\ndeafening bells\nmy god su...
#
#    target  predictions   score
# 0       0            0  0.9453
# 1       0            0  0.9474
# 2       1            1  0.9906
# 3       0            0  0.9020
# 4       1            1  0.9519
# 5       0            0  0.9242
# 6       1            1  0.6246
# 7       0            0  0.9661
# 8       1            0  0.6337
# 9       0            1  0.5445

# %%
# Compute metrics
from src.utils.nlp_metric import Metric
from src.utils.compute_results import get_results

# %%
# Define metrics
metrics_list = ["accuracy", "precision", "recall", "f1"]
metrics = [Metric(metric_name) for metric_name in metrics_list]

target_list = df["target"].tolist()

# Compute metrics
results = get_results(preds=predictions, 
                    labels=target_list, 
                    metrics=metrics)

# %%
# Show results
print(results)
# Out:
# {'accuracy': '0.850', 'precision': '0.833', 'recall': '0.714', 'f1': '0.769'}

# %%
# Show corect predictions
df[df["predictions"] == df["target"]]
# Out:
#        id           keyword                   location  \
# 0    2668             crush          San Diego, Texas.
# 1    7721         panicking                         UK
# 2    7547          outbreak                        NaN
# 3   10687             wreck                        NaN
# 4    4547         emergency                        NaN
# 5   10805           wrecked          probably not home
# 6    2332          collapse                   Fakefams
# 7    3694           destroy                 SEA Server
# 10   5627          flooding                        NaN
# 11  10110          upheaval                     Oregon
# 12    168        aftershock                        NaN
# 14     37               NaN                        NaN
# 15   3068            deaths                Atlanta, GA
# 16    136          accident  Alberta | Sask. | Montana
# 17   9174  suicide%20bomber                        NaN
# 18   9519         terrorist               Niall's arms
# 19   9455         terrorism                    Earth 0
#
#                                                                                           text  \
# 0                                                         love love love remember first crush
# 1                                            may panicking little fast submitting form usually
# 2   families sue legionnaires families affected fatal outbreak legionnaires disease edinburgh
# 3                                                                                        wreck
# 4                                     odai bucharest romania dogs dying they hungry eat other
# 5                                                                                    coleslaw
# 6                                                              correction tent collapse story
# 7                                                                          dazzle destroy fun
# 10              maybe plan dilute safely say start charging over longs would come flooding in
# 11                                                  look state actions year ferguson upheaval
# 12                                                                      ir icemoon aftershock
# 14                                                                          way i can eat shit
# 15                             hear talk avoid thousands resistant infections deaths next yrs
# 16                                                                  suffield alberta accident
# 17                                    suicide bomber kills saudi security site mosque reuters
# 18                                                     idek people actually think he terrorist
# 19                         omega men writer explores terrorism religion kyle rayner story via
#
#     target  predictions   score
# 0        0            0  0.9453
# 1        0            0  0.9474
# 2        1            1  0.9906
# 3        0            0  0.9020
# 4        1            1  0.9519
# 5        0            0  0.9242
# 6        1            1  0.6246
# 7        0            0  0.9661
# 10       0            0  0.9258
# 11       0            0  0.5760
# 12       0            0  0.9664
# 14       0            0  0.9649
# 15       0            0  0.6466
# 16       1            1  0.9739
# 17       1            1  0.9906
# 18       0            0  0.7062
# 19       0            0  0.8559

# %%
# Show incorrect predictions
df[df["predictions"] != df["target"]]
# Out:
#       id               keyword      location  \
# 8    394          annihilation  Chandler, AZ
# 9   5602                 flood           NaN
# 13  4624  emergency%20services           USA
#
#                                                                                                    text  \
# 8         u s national park services tonto national forest stop annihilation salt river wild horse via
# 9   survived plague\nfloated flood\njust peeked heads mud\nno one immune\ndeafening bells\nmy god su...
# 13                                                      call tasmania emergency services trained horse
#
#     target  predictions   score
# 8        1            0  0.6337
# 9        0            1  0.5445
# 13       1            0  0.7050
